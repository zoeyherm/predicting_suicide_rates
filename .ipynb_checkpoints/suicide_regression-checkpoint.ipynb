# %%
import pandas as pd
import numpy as np

import requests
import pickle
import random
import time
from collections import defaultdict

import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels.api as sm
import statsmodels.formula.api as smf

import patsy
import scipy.stats as stats

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, lars_path, ElasticNetCV
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score

# %matplotlib inline

# %%
with open('suicide1.pickle', 'rb') as read_file:
    df = pickle.load(read_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527 entries, 1 to 3129
# Data columns (total 30 columns):
# County_x                              527 non-null object
# County_code                           527 non-null float64
# rate                                  527 non-null float64
# State_x                               527 non-null object
# % Fair/Poor Health                    527 non-null int64
# % LBW                                 527 non-null float64
# % Smokers                             527 non-null int64
# % Obese                               527 non-null int64
# Food Environment Index                527 non-null float64
# % Physically Inactive                 527 non-null int64
# % Excessive Drinking                  527 non-null int64
# % driving deaths Alcohol-Impaired     527 non-null float64
# Teen Birth Rate                       527 non-null float64
# % Uninsured                           527 non-null float64
# PCP Ratio                             527 non-null float64
# Dentist Ratio                         527 non-null float64
# MHP Ratio                             527 non-null float64
# Preventable Hosp. Rate                527 non-null float64
# Graduation Rate                       527 non-null float64
# % Some College                        527 non-null int64
# % Unemployed                          527 non-null float64
# % Children in Poverty                 527 non-null float64
# Income Ratio inequality               527 non-null float64
# % Single-Parent Households            527 non-null float64
# Association Rate                      527 non-null float64
# Violent Crime Rate                    527 non-null float64
# Average Daily PM2.5                   527 non-null float64
# % Severe Housing Problems             527 non-null int64
# % Long Commute - Drives Alone         527 non-null int64
# % With Access eng 1                   527 non-null float64
# dtypes: float64(20), int64(8), object(2)
# memory usage: 127.6+ KB

# %%
df.describe()
# Out:
#        County_code  rate  % Fair/Poor Health  % LBW  % Smokers  % Obese  \
# count        527.0 527.0               527.0  527.0      527.0    527.0
# mean       29063.6  16.6                16.0    8.1       16.2     29.4
# std        15965.9   6.6                 3.6    1.4        3.2      4.7
# min         1003.0   4.0                 8.0    6.0        7.0     14.0
# 25%        13103.0  12.2                13.0    7.0       14.0     26.0
# 50%        30029.0  15.3                16.0    8.0       16.0     30.0
# 75%        42050.0  20.0                18.0    9.0       18.0     33.0
# max        56025.0  47.1                32.0   15.0       27.0     42.0
#
#        Food Environment Index  % Physically Inactive  % Excessive Drinking  \
# count                   527.0                  527.0                 527.0
# mean                      7.7                   22.3                  18.7
# std                       0.9                    4.7                   2.9
# min                       1.8                    9.0                  10.0
# 25%                       7.2                   19.0                  17.0
# 50%                       7.8                   22.0                  19.0
# 75%                       8.3                   26.0                  20.0
# max                      10.0                   35.0                  29.0
#
#        % driving deaths Alcohol-Impaired   ...  % Unemployed  \
# count                               527.0  ...         527.0
# mean                                 29.4  ...           4.4
# std                                   7.4  ...           1.3
# min                                   8.0  ...           2.1
# 25%                                  25.0  ...           3.6
# 50%                                  30.0  ...           4.2
# 75%                                  34.0  ...           5.0
# max                                  55.0  ...          17.0
#
#        % Children in Poverty  Income Ratio inequality  \
# count                  527.0                    527.0
# mean                    17.8                      4.6
# std                      7.4                      0.7
# min                      3.0                      3.2
# 25%                     12.0                      4.1
# 50%                     17.0                      4.5
# 75%                     22.0                      4.9
# max                     44.0                      9.1
#
#        % Single-Parent Households  Association Rate  Violent Crime Rate  \
# count                       527.0             527.0               527.0
# mean                         33.1               9.7               362.1
# std                           8.4               3.1               230.6
# min                          11.0               1.7                33.0
# 25%                          27.0               7.6               200.5
# 50%                          33.0               9.5               312.0
# 75%                          38.5              11.4               454.0
# max                          64.0              27.6              1820.0
#
#        Average Daily PM2.5  % Severe Housing Problems  \
# count                527.0                      527.0
# mean                   9.8                       17.1
# std                    1.9                        4.6
# min                    3.9                        9.0
# 25%                    8.4                       14.0
# 50%                    9.9                       16.0
# 75%                   11.0                       19.0
# max                   19.7                       39.0
#
#        % Long Commute - Drives Alone  % With Access eng 1
# count                          527.0                527.0
# mean                            32.3           54050325.0
# std                             11.5           25309184.7
# min                              8.0             130321.0
# 25%                             23.0           33362176.0
# 50%                             32.0           52200625.0
# 75%                             41.0           74805201.0
# max                             66.0          100000000.0
#
# [8 rows x 28 columns]

# %%
# OLS without patsy

objectdroplist = ['State_x', 'County_code', 'County_x']

X = df.drop(columns=["rate"] + objectdroplist).astype(float)
y = df.loc[:,"rate"].astype(float)

model = sm.OLS(y_trainval, sm.add_constant(X_trainval), data = df)
results = model.fit() 
results.summary()
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rate   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     24.54
# Date:                Tue, 08 Oct 2019   Prob (F-statistic):           1.39e-66
# Time:                        16:58:19   Log-Likelihood:                -1193.3
# No. Observations:                 421   AIC:                             2441.
# Df Residuals:                     394   BIC:                             2550.
# Df Model:                          26
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 84.2226      8.961      9.398      0.000      66.605     101.841
# % Fair/Poor Health                    -0.2059      0.149     -1.383      0.168      -0.499       0.087
# % LBW                                 -0.5465      0.249     -2.195      0.029      -1.036      -0.057
# % Smokers                              0.5805      0.130      4.470      0.000       0.325       0.836
# % Obese                               -0.2210      0.081     -2.716      0.007      -0.381      -0.061
# Food Environment Index                -2.2801      0.444     -5.138      0.000      -3.153      -1.408
# % Physically Inactive                 -0.0467      0.087     -0.534      0.593      -0.218       0.125
# % Excessive Drinking                  -0.2822      0.099     -2.843      0.005      -0.477      -0.087
# % driving deaths Alcohol-Impaired      0.0310      0.031      0.989      0.323      -0.031       0.093
# Teen Birth Rate                        0.1934      0.045      4.339      0.000       0.106       0.281
# % Uninsured                           -0.3294      0.090     -3.650      0.000      -0.507      -0.152
# PCP Ratio                              0.0013      0.001      2.617      0.009       0.000       0.002
# Dentist Ratio                         -0.0015      0.001     -2.948      0.003      -0.002      -0.000
# MHP Ratio                              0.0010      0.001      1.327      0.185      -0.000       0.002
# Preventable Hosp. Rate                -0.0007      0.000     -2.699      0.007      -0.001      -0.000
# Graduation Rate                       -0.0510      0.044     -1.158      0.248      -0.138       0.036
# % Some College                        -0.1568      0.055     -2.858      0.004      -0.265      -0.049
# % Unemployed                          -0.7196      0.284     -2.538      0.012      -1.277      -0.162
# % Children in Poverty                  0.1458      0.090      1.628      0.104      -0.030       0.322
# Income Ratio inequality                0.2665      0.518      0.515      0.607      -0.751       1.284
# % Single-Parent Households            -0.2730      0.069     -3.961      0.000      -0.408      -0.138
# Association Rate                       0.0912      0.102      0.896      0.371      -0.109       0.291
# Violent Crime Rate                    -0.0016      0.001     -1.142      0.254      -0.004       0.001
# Average Daily PM2.5                   -0.8910      0.134     -6.670      0.000      -1.154      -0.628
# % Severe Housing Problems             -0.2075      0.098     -2.109      0.036      -0.401      -0.014
# % Long Commute - Drives Alone         -0.0312      0.028     -1.129      0.260      -0.085       0.023
# % With Access eng 1                 -3.88e-08   1.36e-08     -2.847      0.005   -6.56e-08    -1.2e-08
# ==============================================================================
# Omnibus:                       61.651   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              167.525
# Skew:                           0.702   Prob(JB):                     4.19e-37
# Kurtosis:                       5.753   Cond. No.                     2.52e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.52e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
alphavec = 10**np.linspace(-2,2,200)
l1vec = 10**np.linspace(-2,2,200)

objectdroplist = ['State_x', 'County_code', 'County_x']

X = df.drop(columns=["rate"] + objectdroplist).astype(float)
y = df.loc[:,"rate"].astype(float)
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=.2, random_state=2)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=.25, random_state=2)

# models
lm = LinearRegression()
lm_reg = RidgeCV(alphas = alphavec, cv=5)
lm_la = LassoCV(alphas = alphavec, cv=5,)
lm_en = ElasticNetCV(alphas = alphavec, l1_ratio = 0.6, cv=5)

# fit standard OLS
lm.fit(X_trainval, y_trainval)

# feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_trainval_scaled = scaler.transform(X_trainval)


# fit Ridge
lm_reg.fit(X_trainval_scaled, y_trainval)
    
# fit LASSO
lm_la.fit(X_trainval_scaled, y_trainval)
    
# fit ElasticNet
lm_en.fit(X_trainval_scaled, y_trainval)

# get R^2 values
X_test_scaled = scaler.transform(X_test.values)

lm_pred = lm.predict(X_test)
reg_pred = lm_reg.predict(X_test_scaled)
la_pred = lm_la.predict(X_test_scaled)
en_pred = lm_en.predict(X_test_scaled)


print('R^2 values')

print(f'Simple cv r^2: {(r2_score(y_test, lm_pred))}')
print(f'Ridge cv r^2: {(r2_score(y_test, reg_pred))}')
print(f'LASSO cv r^2: {(r2_score(y_test, la_pred))}')
print(f'ElasticNet cv r^2: {(r2_score(y_test, en_pred))}')


#Mean Absolute Error (MAE)
def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true)) 

print('\nmae values')

a =
b = 
c = 
d = 

print(f'Simple mae: {(mae(y_test, lm_pred))}')
print(f'Ridge mae {(mae(y_test, reg_pred))}')
print(f'LASSO mae: {(mae(y_test, la_pred))}')
print(f'ElasticNet mae: {(mae(y_test, en_pred))}')



# print(lm_la.score(X_test_scaled, y_test))
# Out:
# R^2 values
# Simple cv r^2: 0.6322977800385352
# Ridge cv r^2: 0.6424123190862836
# LASSO cv r^2: 0.6367031182091931
# ElasticNet cv r^2: 0.6395861877488435
#
# mae values
# Simple mae: 2.912130149969658
# Ridge mae 2.8993710010100404
# LASSO mae: 2.9160270140010294
# ElasticNet mae: 2.911954951329244
# 0.6367031182091931

# %%
print(lm_reg.alpha_)
print(lm_la.alpha_)
print(lm_en.alpha_)
# Out:
# 18.896523396912094
# 0.08026433522257174
# 0.05805225516094899

# %%
print(lm.intercept_)
print(lm_reg.intercept_)
print(lm_la.intercept_)
print(lm_en.intercept_)
# Out:
# 84.22257433035776
# 16.92945191547078
# 16.935571074721373
# 16.93010481023108

# %%
X_test_scaled = scaler.transform(X_test.values)

lm_pred = lm.predict(X_test)
reg_pred = lm_reg.predict(X_test_scaled)
la_pred = lm_la.predict(X_test_scaled)
en_pred = lm_en.predict(X_test_scaled)

plt.scatter(df['rate'], y)
plt.scatter(lm_pred, y_test)
plt.scatter(reg_pred, y_test)
plt.scatter(la_pred, y_test)
plt.scatter(en_pred, y_test)

# %%
X_test_scaled = scaler.transform(X_test.values)
X_scaled = scaler.transform(X.values)


lm_pred = lm.predict(X)
reg_pred = lm_reg.predict(X_scaled)
la_pred = lm_la.predict(X_scaled)
en_pred = lm_en.predict(X_scaled)

plt.scatter(lm_pred, y)
plt.scatter(reg_pred, y)
plt.scatter(la_pred, y)
plt.scatter(en_pred, y)
plt.scatter(df['rate'], y)

# %%
X_test.head()
# Out:
#       % Fair/Poor Health  % LBW  % Smokers  % Obese  Food Environment Index  \
# 2117                17.0    8.0       20.0     32.0                     7.4
# 1781                21.0    9.0       16.0     24.0                     8.8
# 2942                20.0   11.0       21.0     30.0                     6.2
# 346                 19.0    9.0       17.0     26.0                     7.5
# 362                 14.0    7.0       16.0     22.0                     7.9
#
#       % Physically Inactive  % Excessive Drinking  \
# 2117                   26.0                  18.0
# 1781                   26.0                  17.0
# 2942                   21.0                  19.0
# 346                    22.0                  20.0
# 362                    22.0                  26.0
#
#       % driving deaths Alcohol-Impaired   Teen Birth Rate  % Uninsured  ...  \
# 2117                                32.0             27.0          6.0  ...
# 1781                                18.0             22.0         14.0  ...
# 2942                                31.0             31.0         12.0  ...
# 346                                 30.0             26.0         14.0  ...
# 362                                 27.0             19.0         20.0  ...
#
#       % Unemployed  % Children in Poverty  Income Ratio inequality  \
# 2117           5.2                   22.0                      4.4
# 1781           4.4                   22.0                      6.1
# 2942           4.4                   35.0                      6.3
# 346            3.8                   21.0                      4.8
# 362            3.3                   18.0                      4.7
#
#       % Single-Parent Households  Association Rate  Violent Crime Rate  \
# 2117                        39.0              12.5               328.0
# 1781                        41.0               4.7               342.0
# 2942                        64.0              14.6               596.0
# 346                         40.0               7.5               312.0
# 362                         34.0              11.8               431.0
#
#       Average Daily PM2.5  % Severe Housing Problems  \
# 2117                 12.2                       13.0
# 1781                  9.9                       29.0
# 2942                  9.3                       24.0
# 346                   7.1                       20.0
# 362                   8.0                       26.0
#
#       % Long Commute - Drives Alone  % With Access eng 1
# 2117                           26.0           40960000.0
# 1781                           51.0          100000000.0
# 2942                           21.0           68574961.0
# 346                            43.0           71639296.0
# 362                            18.0          100000000.0
#
# [5 rows x 26 columns]

# %%
b = list(zip((df.columns[4:]), lm.coef_, lm_reg.coef_, lm_la.coef_, lm_en.coef_))

new = pd.DataFrame.from_records(b, columns =['feature', 'OLS', 'LinReg', 'LASSO', 'ElasticNet']) 
col = new.loc[: , "LinReg":"ElasticNet"]

new['mean'] = col.mean(axis=1)
new['mean_abs'] = abs(new['mean'])
new = new.sort_values('mean_abs', ascending = True)
pd.set_option('display.float_format', lambda x: '%.1f' % x)
new
d = new['mean_abs'].plot.barh()

# %%
new
# Out:
#                                feature  OLS  LinReg  LASSO  ElasticNet  mean  \
# 18             Income Ratio inequality  0.3     0.1    0.1         0.0   0.1
# 5                % Physically Inactive -0.0    -0.1   -0.1        -0.1  -0.1
# 7   % driving deaths Alcohol-Impaired   0.0     0.3    0.2         0.2   0.2
# 20                    Association Rate  0.1     0.3    0.3         0.3   0.3
# 12                           MHP Ratio  0.0     0.3    0.3         0.3   0.3
# 14                     Graduation Rate -0.1    -0.4   -0.3        -0.3  -0.3
# 21                  Violent Crime Rate -0.0    -0.4   -0.4        -0.4  -0.4
# 24       % Long Commute - Drives Alone -0.0    -0.5   -0.3        -0.4  -0.4
# 0                   % Fair/Poor Health -0.2    -0.5   -0.6        -0.5  -0.5
# 16                        % Unemployed -0.7    -0.6   -0.7        -0.6  -0.6
# 17               % Children in Poverty  0.1     0.7    0.8         0.6   0.7
# 10                           PCP Ratio  0.0     0.8    0.8         0.7   0.8
# 6                 % Excessive Drinking -0.3    -0.8   -0.8        -0.8  -0.8
# 13              Preventable Hosp. Rate -0.0    -0.8   -0.9        -0.9  -0.8
# 1                                % LBW -0.5    -0.9   -0.8        -0.9  -0.9
# 3                              % Obese -0.2    -0.8   -1.0        -0.9  -0.9
# 11                       Dentist Ratio -0.0    -0.9   -0.9        -0.9  -0.9
# 23           % Severe Housing Problems -0.2    -1.0   -0.9        -1.0  -1.0
# 25                 % With Access eng 1 -0.0    -1.1   -1.0        -1.1  -1.1
# 15                      % Some College -0.2    -1.0   -1.2        -1.0  -1.1
# 9                          % Uninsured -0.3    -1.0   -1.2        -1.1  -1.1
# 2                            % Smokers  0.6     1.6    1.7         1.6   1.6
# 22                 Average Daily PM2.5 -0.9    -1.6   -1.7        -1.7  -1.7
# 19          % Single-Parent Households -0.3    -1.6   -2.0        -1.7  -1.8
# 4               Food Environment Index -2.3    -1.7   -2.0        -1.8  -1.8
# 8                      Teen Birth Rate  0.2     1.9    2.2         2.1   2.1
#
#     mean_abs
# 18       0.1
# 5        0.1
# 7        0.2
# 20       0.3
# 12       0.3
# 14       0.3
# 21       0.4
# 24       0.4
# 0        0.5
# 16       0.6
# 17       0.7
# 10       0.8
# 6        0.8
# 13       0.8
# 1        0.9
# 3        0.9
# 11       0.9
# 23       1.0
# 25       1.1
# 15       1.1
# 9        1.1
# 2        1.6
# 22       1.7
# 19       1.8
# 4        1.8
# 8        2.1

# %%
plt.scatter(lm_pred, (y_test-lm_pred))

# %% [raw]
# alphavec = 10**np.linspace(-2,2,200)
#
#
# kf = KFold(n_splits=5, shuffle=True, random_state = 42)
# cv_lm_r2s, cv_lm_reg_r2s, cv_lm_la_r2s, cv_lm_en_r2s = [], [], [], [] #collect the validation results for both models
#
# print(kf.split(X, y))
#
# X, y = np.array(X), np.array(y)
#
# for train_ind, val_ind in kf.split(X,y):
#
#     X_train, y_train = X[train_ind], y[train_ind]
#     X_val, y_val = X[val_ind], y[val_ind]
#
#     # models
#     lm = LinearRegression()
#     lm_reg = RidgeCV(alpha=17.5)
#     lm_la = LassoCV(alphas = alphavec, cv=5)
#     lm_en = ElasticNet()
#
#     # fit standard OLS
#     lm.fit(X_train, y_train)
#     cv_lm_r2s.append(lm.score(X_val, y_val))
#
#     # feature scaling
#     scaler = StandardScaler()
#     X_train_scaled = scaler.fit_transform(X_train)
#     X_val_scaled = scaler.transform(X_val)
#
#     # fit Ridge
#     lm_reg.fit(X_train_scaled, y_train)
#     cv_lm_reg_r2s.append(lm_reg.score(X_val_scaled, y_val))
#
#     # fit LASSO
#     lm_la.fit(X_train, y_train)
#     cv_lm_la_r2s.append(lm_la.score(X_val, y_val))
#
#     # fit ElasticNet
#     lm_en.fit(X_train, y_train)
#     cv_lm_en_r2s.append(lm_la.score(X_val, y_val))
#
# print('Simple regression scores: ', cv_lm_r2s)
# print('Ridge scores: ', cv_lm_reg_r2s)
# print('LASSO scores: ', cv_lm_la_r2s)
# print('ElasticNet scores: ', cv_lm_en_r2s, '\n')
#
#
# print(f'Simple mean cv r^2: {np.mean(cv_lm_r2s):.3f} +- {np.std(cv_lm_r2s):.3f}')
# print(f'Ridge mean cv r^2: {np.mean(cv_lm_reg_r2s):.3f} +- {np.std(cv_lm_reg_r2s):.3f}')
# print(f'LASSO mean cv r^2: {np.mean(cv_lm_la_r2s):.3f} +- {np.std(cv_lm_la_r2s):.3f}')
# print(f'ElasticNet mean cv r^2: {np.mean(cv_lm_en_r2s):.3f} +- {np.std(cv_lm_en_r2s):.3f}')

# %%
plt.scatter(lm_pred, (y_test-lm_pred))

# %%
model = sm.OLS(y, X)
fit = model.fit()
df['predict']=fit.predict(X)
df['resid']= y-df.predict
with sns.axes_style('white'):
    plot = df.plot(
        kind='scatter', x='predict', y='resid', alpha=0.5, figsize=(10,6))
